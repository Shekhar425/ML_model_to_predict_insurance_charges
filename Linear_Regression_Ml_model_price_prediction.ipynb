# %% [markdown]
# ## **Linear Regression Handson**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 df=pd.read_csv("C:/Users/Shekhar mishra/Documents/Visual Studio 2017/new_insurance_data.csv")

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1333     1091267.0          1.703805e+08                              2.0
# 1334     1107872.0          2.015152e+08                              2.0
# 1335     1092005.0          2.236450e+08                              2.0
# 1336     1106821.0          2.528924e+08                              3.0
# 1337     1100328.0          2.616317e+08                              3.0
#
#       Anual_Salary     region      charges
# 0     5.578497e+07  southeast   1121.87390
# 1     1.370089e+07  southeast   1131.50660
# 2     7.352311e+07  southeast   1135.94070
# 3     7.581968e+07  southeast   1136.39940
# 4     2.301232e+07  southeast   1137.01100
# ...            ...        ...          ...
# 1333  3.101107e+09  northwest  55135.40209
# 1334  3.484216e+09  northeast  58571.07448
# 1335  3.640807e+09  northwest  60021.39897
# 1336  4.006359e+09  southeast  62592.87309
# 1337  4.117197e+09  southeast  63770.42801
#
# [1338 rows x 13 columns]

# %% [markdown]
# # The above dataset consist of historical data of past clients, has been given by Insuarance company.
# # Problem Statement : Create an ML model that can Predict the insurance charges of the new clients.

# %% [markdown]
# **EDA - Exploratory Data Analysis**
#
# Data cleaning
#
# datatypes
#
# null values
#
# duplicate
#
# dealing with outliers
#
# Visual Analyis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(52)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1333     1091267.0          1.703805e+08                              2.0
# 1334     1107872.0          2.015152e+08                              2.0
# 1335     1092005.0          2.236450e+08                              2.0
# 1336     1106821.0          2.528924e+08                              3.0
# 1337     1100328.0          2.616317e+08                              3.0
#
#       Anual_Salary     region      charges
# 0     5.578497e+07  southeast   1121.87390
# 1     1.370089e+07  southeast   1131.50660
# 2     7.352311e+07  southeast   1135.94070
# 3     7.581968e+07  southeast   1136.39940
# 4     2.301232e+07  southeast   1137.01100
# ...            ...        ...          ...
# 1333  3.101107e+09  northwest  55135.40209
# 1334  3.484216e+09  northeast  58571.07448
# 1335  3.640807e+09  northwest  60021.39897
# 1336  4.006359e+09  southeast  62592.87309
# 1337  4.117197e+09  southeast  63770.42801
#
# [1287 rows x 13 columns]

# %%
#  checking the duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# in case we have duplicates
# df.drop_duplicates(inplace=True)

# %%
#checking for outliers  ---

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
for col in df.columns:
  if df[col].dtype!="object":
    plt.boxplot(df[col])
    plt.title(col)
    plt.show()

# %%
df['NUmber_of_past_hospitalizations'].value_counts()
# Out:
# NUmber_of_past_hospitalizations
# 1.0    927
# 2.0    221
# 0.0    137
# 3.0      2
# Name: count, dtype: int64

# %%
out_cols=['bmi','past_consultations','Hospital_expenditure','Anual_Salary','charges']

# %%
for col in out_cols:
  Q1=df[col].quantile(0.25)
  Q3=df[col].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df=df[(df[col]>=lower_limit) & (df[col]<=upper_limit)]

# %%
df
# Out:
#        age     sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.21       0.0     no   29087.54313                17.0
# 1     18.0    male  30.14       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.33       0.0     no   39023.62759                19.0
# 3     18.0    male  33.66       0.0     no   28185.39332                11.0
# 4     18.0    male  34.10       0.0     no   14697.85941                16.0
# ...    ...     ...    ...       ...    ...           ...                 ...
# 1036  43.0    male  20.13       2.0    yes   44184.65414                19.0
# 1041  24.0  female  27.60       0.0     no   27184.27803                 9.0
# 1046  29.0  female  27.94       1.0    yes   51168.25474                23.0
# 1048  31.0    male  25.90       3.0    yes   46619.40230                27.0
# 1050  31.0    male  29.81       0.0    yes   24382.58056                21.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1036      984247.0          1.473451e+07                              1.0
# 1041      980010.0          1.266673e+07                              1.0
# 1046      993751.0          1.665982e+07                              1.0
# 1048      989387.0          1.361938e+07                              1.0
# 1050      973924.0          1.028991e+07                              1.0
#
#       Anual_Salary     region      charges
# 0     5.578497e+07  southeast   1121.87390
# 1     1.370089e+07  southeast   1131.50660
# 2     7.352311e+07  southeast   1135.94070
# 3     7.581968e+07  southeast   1136.39940
# 4     2.301232e+07  southeast   1137.01100
# ...            ...        ...          ...
# 1036  3.687871e+08  southeast  18767.73770
# 1041  3.743228e+08  southwest  18955.22017
# 1046  3.712188e+08  southeast  19107.77960
# 1048  3.812895e+08  southwest  19199.94400
# 1050  3.745310e+08  southeast  19350.36890
#
# [986 rows x 13 columns]

# %%
# #Visual Analysis
# Create different plots to know relations or inferences from the data

# %%
# Data preprocessing

#label Encoding
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["sex"]=le.fit_transform(df["sex"])
df["smoker"]=le.fit_transform(df["smoker"])
df["region"]=le.fit_transform(df["region"])

# %%
df
# Out:
#        age  sex    bmi  children  smoker  Claim_Amount  past_consultations  \
# 0     18.0    1  23.21       0.0       0   29087.54313                17.0
# 1     18.0    1  30.14       0.0       0   39053.67437                 7.0
# 2     18.0    1  33.33       0.0       0   39023.62759                19.0
# 3     18.0    1  33.66       0.0       0   28185.39332                11.0
# 4     18.0    1  34.10       0.0       0   14697.85941                16.0
# ...    ...  ...    ...       ...     ...           ...                 ...
# 1036  43.0    1  20.13       2.0       1   44184.65414                19.0
# 1041  24.0    0  27.60       0.0       0   27184.27803                 9.0
# 1046  29.0    0  27.94       1.0       1   51168.25474                23.0
# 1048  31.0    1  25.90       3.0       1   46619.40230                27.0
# 1050  31.0    1  29.81       0.0       1   24382.58056                21.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1036      984247.0          1.473451e+07                              1.0
# 1041      980010.0          1.266673e+07                              1.0
# 1046      993751.0          1.665982e+07                              1.0
# 1048      989387.0          1.361938e+07                              1.0
# 1050      973924.0          1.028991e+07                              1.0
#
#       Anual_Salary  region      charges
# 0     5.578497e+07       2   1121.87390
# 1     1.370089e+07       2   1131.50660
# 2     7.352311e+07       2   1135.94070
# 3     7.581968e+07       2   1136.39940
# 4     2.301232e+07       2   1137.01100
# ...            ...     ...          ...
# 1036  3.687871e+08       2  18767.73770
# 1041  3.743228e+08       3  18955.22017
# 1046  3.712188e+08       2  19107.77960
# 1048  3.812895e+08       3  19199.94400
# 1050  3.745310e+08       2  19350.36890
#
# [986 rows x 13 columns]

# %% [markdown]
# # **Feature Selection**

# %%
# correlation
#VIF- variance inflation factor
#RFE -- Recursive Feature Elimination
# etc

# %%
# correlation
df.corr()
# Out:
#                                       age       sex       bmi  children  \
# age                              1.000000 -0.003647  0.157363  0.046903
# sex                             -0.003647  1.000000  0.010777  0.022200
# bmi                              0.157363  0.010777  1.000000  0.012556
# children                         0.046903  0.022200  0.012556  1.000000
# smoker                          -0.205838  0.020767 -0.203690 -0.028992
# Claim_Amount                     0.106907 -0.033575  0.013019  0.037777
# past_consultations               0.178307  0.001858  0.017543  0.043747
# num_of_steps                     0.763756 -0.058674  0.043881  0.219064
# Hospital_expenditure             0.161881 -0.004635  0.013951 -0.008496
# NUmber_of_past_hospitalizations  0.527364 -0.082260  0.022507  0.309678
# Anual_Salary                     0.508866 -0.025345  0.007997  0.066027
# region                           0.018011 -0.017551  0.160247  0.049654
# charges                          0.682315 -0.039046  0.019630  0.131216
#
#                                    smoker  Claim_Amount  past_consultations  \
# age                             -0.205838      0.106907            0.178307
# sex                              0.020767     -0.033575            0.001858
# bmi                             -0.203690      0.013019            0.017543
# children                        -0.028992      0.037777            0.043747
# smoker                           1.000000      0.144309            0.141036
# Claim_Amount                     0.144309      1.000000            0.070665
# past_consultations               0.141036      0.070665            1.000000
# num_of_steps                     0.297142      0.187298            0.265269
# Hospital_expenditure             0.274776      0.050630            0.088732
# NUmber_of_past_hospitalizations  0.084012      0.108704            0.135027
# Anual_Salary                     0.506264      0.169931            0.273144
# region                          -0.016182      0.004817            0.022856
# charges                          0.435330      0.194932            0.286770
#
#                                  num_of_steps  Hospital_expenditure  \
# age                                  0.763756              0.161881
# sex                                 -0.058674             -0.004635
# bmi                                  0.043881              0.013951
# children                             0.219064             -0.008496
# smoker                               0.297142              0.274776
# Claim_Amount                         0.187298              0.050630
# past_consultations                   0.265269              0.088732
# num_of_steps                         1.000000              0.309669
# Hospital_expenditure                 0.309669              1.000000
# NUmber_of_past_hospitalizations      0.715836              0.131773
# Anual_Salary                         0.794464              0.378125
# region                              -0.044130              0.019383
# charges                              0.942969              0.366163
#
#                                  NUmber_of_past_hospitalizations  \
# age                                                     0.527364
# sex                                                    -0.082260
# bmi                                                     0.022507
# children                                                0.309678
# smoker                                                  0.084012
# Claim_Amount                                            0.108704
# past_consultations                                      0.135027
# num_of_steps                                            0.715836
# Hospital_expenditure                                    0.131773
# NUmber_of_past_hospitalizations                         1.000000
# Anual_Salary                                            0.373849
# region                                                 -0.049122
# charges                                                 0.532328
#
#                                  Anual_Salary    region   charges
# age                                  0.508866  0.018011  0.682315
# sex                                 -0.025345 -0.017551 -0.039046
# bmi                                  0.007997  0.160247  0.019630
# children                             0.066027  0.049654  0.131216
# smoker                               0.506264 -0.016182  0.435330
# Claim_Amount                         0.169931  0.004817  0.194932
# past_consultations                   0.273144  0.022856  0.286770
# num_of_steps                         0.794464 -0.044130  0.942969
# Hospital_expenditure                 0.378125  0.019383  0.366163
# NUmber_of_past_hospitalizations      0.373849 -0.049122  0.532328
# Anual_Salary                         1.000000 -0.036990  0.908877
# region                              -0.036990  1.000000 -0.041278
# charges                              0.908877 -0.041278  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
imp_col=['age','num_of_steps','NUmber_of_past_hospitalizations', 'Anual_Salary']

# %%
imp_col
# Out:
# ['age', 'num_of_steps', 'NUmber_of_past_hospitalizations', 'Anual_Salary']

# %%
# Defining the independent and dependent columns
X=df[imp_col]
X  # independent variables
# Out:
#        age  num_of_steps  NUmber_of_past_hospitalizations  Anual_Salary
# 0     18.0      715428.0                              0.0  5.578497e+07
# 1     18.0      699157.0                              0.0  1.370089e+07
# 2     18.0      702341.0                              0.0  7.352311e+07
# 3     18.0      700250.0                              0.0  7.581968e+07
# 4     18.0      711584.0                              0.0  2.301232e+07
# ...    ...           ...                              ...           ...
# 1036  43.0      984247.0                              1.0  3.687871e+08
# 1041  24.0      980010.0                              1.0  3.743228e+08
# 1046  29.0      993751.0                              1.0  3.712188e+08
# 1048  31.0      989387.0                              1.0  3.812895e+08
# 1050  31.0      973924.0                              1.0  3.745310e+08
#
# [986 rows x 4 columns]

# %%
y=df["charges"]
y
# Out:
# 0        1121.87390
# 1        1131.50660
# 2        1135.94070
# 3        1136.39940
# 4        1137.01100
#            ...
# 1036    18767.73770
# 1041    18955.22017
# 1046    19107.77960
# 1048    19199.94400
# 1050    19350.36890
# Name: charges, Length: 986, dtype: float64

# %% [markdown]
# # **Model Building part**

# %%
#splitting data into training and testing
#defining a model
#training a model
#testing a model
#Evaluation of performance of model

# %%
#splitting data into training and testing
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=7)

# %%
x_train
# Out:
#       age  num_of_steps  NUmber_of_past_hospitalizations  Anual_Salary
# 83   20.0      760215.0                              0.0  5.323287e+07
# 981  62.0      962029.0                              1.0  3.199317e+08
# 636  50.0      922210.0                              1.0  1.188551e+08
# 352  29.0      851625.0                              1.0  8.499737e+07
# 347  25.0      859982.0                              1.0  1.100850e+08
# ..    ...           ...                              ...           ...
# 619  49.0      900391.0                              1.0  1.343365e+08
# 537  44.0      891626.0                              1.0  1.201369e+08
# 572  46.0      895100.0                              1.0  1.177695e+08
# 213  28.0      822164.0                              1.0  4.703397e+07
# 191  25.0      787584.0                              1.0  2.332156e+07
#
# [690 rows x 4 columns]

# %%
y_train
# Out:
# 83      1964.78000
# 981    15019.76005
# 636     8827.20990
# 352     4906.40965
# 347     4877.98105
#           ...
# 619     8601.32930
# 537     7419.47790
# 572     8026.66660
# 213     3277.16100
# 191     3021.80915
# Name: charges, Length: 690, dtype: float64

# %%
x_test
# Out:
#       age  num_of_steps  NUmber_of_past_hospitalizations  Anual_Salary
# 906  55.0      942032.0                              1.0  2.008540e+08
# 290  34.0      851188.0                              1.0  1.068418e+08
# 305  28.0      844793.0                              1.0  5.843714e+07
# 970  63.0      945893.0                              1.0  2.491297e+08
# 254  21.0      821333.0                              1.0  1.127089e+08
# ..    ...           ...                              ...           ...
# 605  45.0      922646.0                              1.0  1.227101e+08
# 481  33.0      889432.0                              1.0  1.043240e+08
# 856  58.0      940048.0                              1.0  1.987985e+08
# 204  21.0      814668.0                              1.0  5.602968e+07
# 268  32.0      842720.0                              1.0  7.426531e+07
#
# [296 rows x 4 columns]

# %%
y_test
# Out:
# 906    13047.33235
# 290     4320.41085
# 305     4438.26340
# 970    14451.83515
# 254     3861.20965
#           ...
# 605     8515.75870
# 481     6666.24300
# 856    12222.89830
# 204     3180.51010
# 268     3994.17780
# Name: charges, Length: 296, dtype: float64

# %% [markdown]
# # **Model Building **

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()   # raw model/ new born child who have not learnt any thing

# %%
#training the model
model.fit(x_train,y_train)
# model has been trained
# Out:
# LinearRegression()

# %%
#testing the model
pred=model.predict(x_test)
pred
# Out:
# array([12181.83809947,  5876.54605066,  4687.72214884, 13230.05705252,
#         4499.71846846,  5685.14670832,   779.47836465,   285.24064721,
#         2882.71030354,  2967.49681003,  2856.79860571, 10770.08631116,
#        11184.36985528,  4175.50559237, 11856.88802806,  1609.1205661 ,
#        17513.73615454, 11469.19507355, 17503.87958162,   643.56670171,
#         3672.47745752, 14767.42977829, 13332.07924456,   229.37371777,
#         2303.79035132,  4026.48229491,  3932.47159575,  9291.21874962,
#         8323.1309532 , 16196.32548025, 13484.76523279,  4564.75133461,
#        11260.42972872,  4268.76571753,  6049.17976853,  9228.89558711,
#        11873.59452791,  6966.87560427,  6767.69988532, 12658.40055711,
#         6765.68224422,  9437.71829147,  4444.47546862,  8891.16780123,
#          576.35573947,  1542.45418174, 10455.00567036,  9870.20253379,
#        17424.89510904,  5511.91170672, 18006.6064333 ,  3996.99315227,
#        16165.94410257, 10124.15604381, 16422.51338039,  8296.46091002,
#         9910.57258559, 15200.14151269,  2027.70582946,  9489.47951651,
#        13006.55686591,  7530.12549685, 11881.13974415,  5555.73590942,
#         4110.69429865,  8787.4241295 ,  5819.83694983, 10920.8375289 ,
#        10794.7594341 ,  2469.61519728, 11422.78828864,  2760.75752422,
#        11549.85311914,  9222.91063987,   272.49660595, 16675.42668654,
#        11487.56478993, 10102.58132814,  6699.99930858, 14475.87150335,
#         1461.02326521,  2677.67990181, 14488.46595646,  1933.53533804,
#        14689.49312902,  1950.32125126, 12717.93889534, 17074.86467682,
#        10583.39151507, 13032.3341792 ,  6978.51055412,  7952.01766723,
#        11992.17204926, 15128.37200303,  6086.71623159,  5383.84561911,
#         4087.09844512, 14364.85996275,  1715.49419096,  9018.62202539,
#         8694.84063997,  4666.80856777,  9316.60380919,  4755.08810411,
#         2513.47651551,  1186.49884423, 11176.77599161, 13635.52679044,
#        11413.03139388, 13093.67116962, 16407.27982611,  6845.4956029 ,
#         1854.49722115,  8056.77893283,  8667.417565  ,  9068.86931819,
#        17285.06352271,   -92.70042542, 10477.51481422,  8977.92162234,
#         9642.08760367,   794.07335268, 10356.87276407, 10533.45806801,
#        11645.61171171,  7786.76671195, 13277.82079931, 12135.93430393,
#        11061.00492707,  4441.51036374,  2023.63096327,  6099.46891525,
#         8242.01004351, 12386.04265357,  8077.79996945,  7455.960775  ,
#         6740.38478111, 14635.19289417, 11642.09215503,  2763.03480385,
#        15287.05649748,  3060.044079  , 17087.9433013 ,  8738.13587645,
#         7780.97822433,  8692.35732273, 10671.87486786, 13846.94845961,
#         8287.46691432, 11210.01480834,  4124.23963893,  9751.22495832,
#        14475.01861261,  5449.77238385,  6636.11876578, 11939.05539423,
#        11305.4560773 , 11974.28150097,  8714.63739204,  6607.96950293,
#         8567.80393785,  7602.86496795,  2777.21751155,  3414.60387994,
#          938.96404923,  4991.43382767,  6491.32938077,  7170.50197897,
#         1797.69084804,  2036.77063181,  7066.18472779, 11392.65337685,
#         6090.75613671, 10269.14962057,  6563.99695947, 11204.5138651 ,
#         9323.53033309,  7321.52482441,  7456.97689882,  9038.78703062,
#         6245.39541593,  2745.50425975, 10140.07980537,  6211.47807725,
#        10638.31547347,  4753.36367982,  5500.3892213 , 11483.29633996,
#        15813.63897054,  4766.18015785,  5272.44067338,  2897.34563645,
#         1639.39459521,  6965.28560938,  8391.95069406,  9834.06616864,
#         8178.314016  , 10279.02115624,  7069.45832326,  9630.01707226,
#        12072.15937086, 10502.35628239,  4604.859755  ,  1729.47321037,
#         8361.61842747,  5108.68436982, 10814.53370728,  2958.47012403,
#         8461.23201484,  6027.48296996, 10071.64491565, 13307.60726115,
#        14124.29763151,  8456.68619667, 12192.86715645,  7210.32899247,
#         4337.69469501, 15915.64120355,  9307.11797008, 12013.61356706,
#         1155.01582693,  7158.45870613,  5061.40173891,  6451.22080289,
#        14898.0220711 , 15880.02318283,  8283.55397415, 12693.44134994,
#        11114.16541681,  6387.24110214, 16849.57782712, 12901.26626555,
#         1564.97822617, 10307.18214169,  2302.85599602,  2663.62835946,
#         1628.0201138 ,  5306.0154837 , 11594.68227274, 12803.36165902,
#         5292.06072007,  5885.65631898,   213.27790295,   498.88600081,
#         8908.72979434,  2523.05880323,  9872.3309702 ,  1149.53330188,
#         9778.08584443, 12519.92144043, 11326.30345511,  9902.93521574,
#         -135.87818109, 13481.15304768,  3562.57401367,  7262.44753781,
#         8935.96439242,  2741.96491099,  4882.54648341,  3097.41465071,
#         1797.04585201,  3063.71256488, 11407.04651389,  9396.8595213 ,
#         2109.04570275,  7022.17397296, 10152.69048555, 12845.11863024,
#         3393.38988063, 10980.3854368 , 10633.75071647,  5777.86429511,
#         8610.55044412,  7932.98800296,  7671.58266524,  1097.50857458,
#        10720.43843104,  3284.96751963,  6207.84718312, 10443.95708151,
#         7447.6175752 ,  1959.34161085,  5232.78404439, 11811.57826909,
#        11375.72963866,  8828.0983175 ,  8019.85381431,  4123.43037752,
#         9709.54873715, 10482.43724272,  5207.22496902,  9797.79273453,
#         7801.46197767, 12030.38301469,  3122.16137673,  4854.22140144])

# %%
y_test
# Out:
# 906    13047.33235
# 290     4320.41085
# 305     4438.26340
# 970    14451.83515
# 254     3861.20965
#           ...
# 605     8515.75870
# 481     6666.24300
# 856    12222.89830
# 204     3180.51010
# 268     3994.17780
# Name: charges, Length: 296, dtype: float64

# %%
# Evaluation of the model
from sklearn.metrics import   *

# %%
# How : worst your model is : go for Error parameters:  Root mean squared Error
rmse=np.sqrt(mean_squared_error(y_test,pred))
rmse
# Out:
# np.float64(804.6719666896222)

# %%
Error_df =pd.DataFrame({"actual":y_test,"predicted":pred})

# %%
Error_df
# Out:
#           actual     predicted
# 906  13047.33235  12181.838099
# 290   4320.41085   5876.546051
# 305   4438.26340   4687.722149
# 970  14451.83515  13230.057053
# 254   3861.20965   4499.718468
# ..           ...           ...
# 605   8515.75870   9797.792735
# 481   6666.24300   7801.461978
# 856  12222.89830  12030.383015
# 204   3180.51010   3122.161377
# 268   3994.17780   4854.221401
#
# [296 rows x 2 columns]

# %%
Error_df["Error"]=Error_df["actual"] -Error_df["predicted"]

# %%
Error_df
# Out:
#           actual     predicted        Error
# 906  13047.33235  12181.838099   865.494251
# 290   4320.41085   5876.546051 -1556.135201
# 305   4438.26340   4687.722149  -249.458749
# 970  14451.83515  13230.057053  1221.778097
# 254   3861.20965   4499.718468  -638.508818
# ..           ...           ...          ...
# 605   8515.75870   9797.792735 -1282.034035
# 481   6666.24300   7801.461978 -1135.218978
# 856  12222.89830  12030.383015   192.515285
# 204   3180.51010   3122.161377    58.348723
# 268   3994.17780   4854.221401  -860.043601
#
# [296 rows x 3 columns]

# %%
#hOW GOOD YOUR MODEL IS :
r2_score(y_test,pred)*100
# Out:
# 96.67311195985194
